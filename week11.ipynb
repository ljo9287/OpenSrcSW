# %%
def copy(fname, fcopy):
    f1 = open(fname, 'r')
    f2 = open(fcopy, 'w')

    data = f1.read()
    f2.write(data)

    print(data)

    f1.close()
    f2.close()
    
if __name__ == '__main__':
    fname = input('file1')
    fcopy = input('file2')

    copy(fname, fcopy)
# Out:
# file1hello.txt
# file2hi.txt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-d8ac22dfcb0c> in <module>
#      15     fcopy = input('file2')
#      16
# ---> 17     copy(fname, fcopy)
#
# <ipython-input-8-d8ac22dfcb0c> in copy(fname, fcopy)
#       1 def copy(fname, fcopy):
# ----> 2     f1 = open(fname, 'r')
#       3     f2 = open(fcopy, 'w')
#       4
#       5     data = f1.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hello.txt'

# %%
def wc(fname):
    dic = {}
    f = open(fname, 'r')
    print('lines:',len(f.readlines()))
    f.close()

    f = open(fname, 'r')

    for line in f:
        line = line.replace('\n', '')
        words = line.split()
        for word in words:
            if word in dic:
                dic[word] += 1
            else:
                dic[word] = 1
    for word in dic:
        print(word, dic[word])

    f.close()

if __name__ == '__main__':
    fname = input('fname: ')
    wc(fname)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d8ac22dfcb0c> in <module>
#      12
#      13 if __name__ == '__main__':
# ---> 14     fname = input('file1')
#      15     fcopy = input('file2')
#      16
#
# c:\users\이재욱\appdata\local\programs\python\python39\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     846                 "raw_input was called, but this frontend does not support input requests."
#     847             )
# --> 848         return self._input_request(str(prompt),
#     849             self._parent_ident,
#     850             self._parent_header,
#
# c:\users\이재욱\appdata\local\programs\python\python39\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     890             except KeyboardInterrupt:
#     891                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 892                 raise KeyboardInterrupt("Interrupted by user") from None
#     893             except Exception as e:
#     894                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
class Calc:

    def sum(self, a, b):
        result = a + b
        print('{0} + {1} = {2}'.format(a, b, result))
        
    def sub(self, a, b):
        result = a - b
        print('{0} - {1} = {2}'.format(a, b, result))
        
    def multi(self, a, b):
        result = a * b
        print('{0} * {1} = {2}'.format(a, b, result))

    def divi(self, a, b):
        result = a / b
        print('{0} / {1} = {2}'.format(a, b, result))


if __name__ == '__main__':
    print('calc_ex')
    a = Calc()
    
    print(a.sum(1,2))
    print(a.sub(1,2))
    print(a.multi(1,2))
    print(a.divi(1,2))
# Out:
# calc_ex
# 1 + 2 = 3
# None
# 1 - 2 = -1
# None
# 1 * 2 = 2
# None
# 1 / 2 = 0.5
# None

# %%
a=input()
stack=[]
res=''
ans = []

#중위식 -> 후위식
for x in a:
    if x.isdecimal():
        res += x
    else:
        
        if x=='*' or x=='/':
            while stack and (stack[-1]=='*' or stack[-1]=='/'):
                res+=stack.pop()
            stack.append(x)
        elif x=='+' or x=='-':
            while stack:
                res+=stack.pop()
            stack.append(x)
       
while stack:
    res+=stack.pop()
print(res)

operations = {
            '*': lambda x, y: y * x,
            '/': lambda x, y: y / x,
            '+': lambda x, y: y + x,
            '-': lambda x, y: y - x
            }


for x in res:
    if x not in operations:
        stack.append(int(x))

    elif x == '+':
        n1 = stack.pop()
        n2 = stack.pop()
        stack.append(operations[x](n1,n2))

    elif x == '-':
        n1 = stack.pop()
        n2 = stack.pop()
        stack.append(operations[x](n1,n2))
    
    elif x == '*':
        n1 = stack.pop()
        n2 = stack.pop()
        stack.append(operations[x](n1,n2))

    elif x == '/':
        n1 = stack.pop()
        n2 = stack.pop()
        stack.append(operations[x](n1,n2))
        
for i in stack:
    ans.append(i)
print(ans)
# Out:
# 3+5*8-7
# 358*+7-
# [36]
