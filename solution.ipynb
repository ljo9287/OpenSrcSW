# %%
import csv
f = open('seoul.csv')
data = csv.reader(f)
heaer = next(data)
min = -999
date = ''
s = []
sumA = []
for row in data:
    row[-1] = float(row[-1])
    row[-2] = float(row[-2])

    s.append(row[-1] - row[-2])

sum1 = sum(s[:7])
sum2 = sum(s[7:14])
sum3 = sum(s[14:21])
sum4 = sum(s[21:28])
sum5 = sum(s[28:])

#print(sum1,sum2,sum3,sum4,sum5)

print('Max Week = 5/8 ~ 5/14')
f.close()
